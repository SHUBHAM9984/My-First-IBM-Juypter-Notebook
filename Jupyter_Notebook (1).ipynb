# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Shubham Kumar Rajak**
#
# Currently i am a student and my desire occupation to become a Data Analyst

# %% [markdown]
# *I am interested in data science because i am curious about what happening in the data how we predict modeling with the pervious data*

# %% [markdown]
# ### I create a code of simple addition ,multiplication, Devioion and so on

# %%
a=2+4 # Addition 
b=2-4 # Subtraction
c=2*4 # Multiplication
d=2/4 # Devision
e=2//4 # Quotient
f=2**4 # power
g=2%4 # Modulus

# %%
a,b,c,d,e,f,g
# Out:
# (6, -2, 8, 0.5, 0, 16, 2)

# %% [markdown]
#  -----
# * Bullet
#
#
# 1. Number list
#
# Table1 | Table2 |Table3
# -------|--------|------
# 1      |2       |3
# *String*|**String**|`String`
#
# https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#links
#
# ![.](attachment:ef36b60f-d812-4e4a-94d3-c80050173fa5.jpg)
